# %% [markdown]
# # Working With Dates in Pandas

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Datetime Types

# %%
pd.to_datetime('now')
# Out:
# Timestamp('2021-10-01 21:07:27.058606')

# %%
# pd.to_datetime('Jan:1:1970')

# %%
pd.to_datetime('Jan:1:1970', format='%b:%d:%Y')
# Out:
# Timestamp('1970-01-01 00:00:00')

# %%
url = "https://gist.githubusercontent.com/ryanorsinger/b309f8db19e0ca71b213d4877d835e77/raw/f5841017310e2f4ca070b313529ceec2375336ba/coffee_consumption.csv"
df = pd.read_csv(url)
df.head()
# Out:
#          date  coffee_consumption
# 0  2019-01-01           14.301915
# 1  2019-01-02           12.905900
# 2  2019-01-03           10.046015
# 3  2019-01-04            6.354805
# 4  2019-01-07            8.545563

# %%
pd.to_datetime(df.date)
# Out:
# 0     2019-01-01
# 1     2019-01-02
# 2     2019-01-03
# 3     2019-01-04
# 4     2019-01-07
#          ...
# 256   2019-12-25
# 257   2019-12-26
# 258   2019-12-27
# 259   2019-12-30
# 260   2019-12-31
# Name: date, Length: 261, dtype: datetime64[ns]

# %%
df.date = pd.to_datetime(df.date)
df.dtypes
# Out:
# date                  datetime64[ns]
# coffee_consumption           float64
# dtype: object

# %% [markdown]
# ## `.dt` accessor

# %%
df.date.dt.quarter
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 256    4
# 257    4
# 258    4
# 259    4
# 260    4
# Name: date, Length: 261, dtype: int64

# %% [markdown]
# How many observations are there for each month? Each weekday?

# %%
df.date.dt.month.value_counts().sort_index()
# Out:
# 1     23
# 2     20
# 3     21
# 4     22
# 5     23
# 6     20
# 7     23
# 8     22
# 9     21
# 10    23
# 11    21
# 12    22
# Name: date, dtype: int64

# %%
df['month'] = df.date.dt.month

# %%
df.head()
# Out:
#         date  coffee_consumption  month
# 0 2019-01-01           14.301915      1
# 1 2019-01-02           12.905900      1
# 2 2019-01-03           10.046015      1
# 3 2019-01-04            6.354805      1
# 4 2019-01-07            8.545563      1

# %%
df.month.value_counts().sort_index()
# Out:
# 1     23
# 2     20
# 3     21
# 4     22
# 5     23
# 6     20
# 7     23
# 8     22
# 9     21
# 10    23
# 11    21
# 12    22
# Name: month, dtype: int64

# %%
pd.__version__
# Out:
# '1.2.4'

# %% [markdown]
# Use `.weekday_name()` if you are using pandas < 1.x

# %%
df['weekday'] = df.date.dt.day_name()
df.weekday.value_counts()
# Out:
# Tuesday      53
# Friday       52
# Wednesday    52
# Thursday     52
# Monday       52
# Name: weekday, dtype: int64

# %% [markdown]
# ## DateTime Indexes

# %%
df = df.set_index('date').sort_index()
df
# Out:
#             coffee_consumption  month    weekday
# date
# 2019-01-01           14.301915      1    Tuesday
# 2019-01-02           12.905900      1  Wednesday
# 2019-01-03           10.046015      1   Thursday
# 2019-01-04            6.354805      1     Friday
# 2019-01-07            8.545563      1     Monday
# ...                        ...    ...        ...
# 2019-12-25           12.250875     12  Wednesday
# 2019-12-26            7.513206     12   Thursday
# 2019-12-27            9.464345     12     Friday
# 2019-12-30           14.623106     12     Monday
# 2019-12-31           10.168315     12    Tuesday
#
# [261 rows x 3 columns]

# %%
# earliest + latest dates
df.index.min(), df.index.max()
# Out:
# (Timestamp('2019-01-01 00:00:00'), Timestamp('2019-12-31 00:00:00'))

# %%
# Month of March
df.loc['2019-03-01':'2019-03-13']
# Out:
#             coffee_consumption  month    weekday
# date
# 2019-03-01            9.109061      3     Friday
# 2019-03-04            9.054681      3     Monday
# 2019-03-05            9.915438      3    Tuesday
# 2019-03-06           11.254156      3  Wednesday
# 2019-03-07            5.680393      3   Thursday
# 2019-03-08            8.823756      3     Friday
# 2019-03-11           11.296137      3     Monday
# 2019-03-12            6.552509      3    Tuesday
# 2019-03-13           10.784550      3  Wednesday

# %%
# Subset of march

# %% [markdown]
# ### Resampling

# %% [markdown]
# Upsampling: (generally) increase # of rows + introduce nulls

# %%
by_day = df.asfreq('D')
by_day.head(10)
# Out:
#             coffee_consumption  month    weekday
# date
# 2019-01-01           14.301915    1.0    Tuesday
# 2019-01-02           12.905900    1.0  Wednesday
# 2019-01-03           10.046015    1.0   Thursday
# 2019-01-04            6.354805    1.0     Friday
# 2019-01-05                 NaN    NaN        NaN
# 2019-01-06                 NaN    NaN        NaN
# 2019-01-07            8.545563    1.0     Monday
# 2019-01-08            9.410101    1.0    Tuesday
# 2019-01-09            7.219271    1.0  Wednesday
# 2019-01-10            9.338456    1.0   Thursday

# %%
by_day.assign(
    ffill=lambda df: df.coffee_consumption.ffill(),
    bfill=lambda df: df.coffee_consumption.bfill()
).head(15)
# Out:
#             coffee_consumption  month    weekday      ffill      bfill
# date
# 2019-01-01           14.301915    1.0    Tuesday  14.301915  14.301915
# 2019-01-02           12.905900    1.0  Wednesday  12.905900  12.905900
# 2019-01-03           10.046015    1.0   Thursday  10.046015  10.046015
# 2019-01-04            6.354805    1.0     Friday   6.354805   6.354805
# 2019-01-05                 NaN    NaN        NaN   6.354805   8.545563
# 2019-01-06                 NaN    NaN        NaN   6.354805   8.545563
# 2019-01-07            8.545563    1.0     Monday   8.545563   8.545563
# 2019-01-08            9.410101    1.0    Tuesday   9.410101   9.410101
# 2019-01-09            7.219271    1.0  Wednesday   7.219271   7.219271
# 2019-01-10            9.338456    1.0   Thursday   9.338456   9.338456
# 2019-01-11           11.872667    1.0     Friday  11.872667  11.872667
# 2019-01-12                 NaN    NaN        NaN  11.872667   9.198816
# 2019-01-13                 NaN    NaN        NaN  11.872667   9.198816
# 2019-01-14            9.198816    1.0     Monday   9.198816   9.198816
# 2019-01-15           11.753337    1.0    Tuesday  11.753337  11.753337

# %%
df = df.fillna(0)

# %% [markdown]
# Downsampling: reduce the number of rows and aggregate
#
# like a group by -- but time is the category

# %%
del df['month']

# %%
df.resample('W').sum()
# Out:
#             coffee_consumption
# date
# 2019-01-06           43.608635
# 2019-01-13           46.386058
# 2019-01-20           51.325487
# 2019-01-27           48.451299
# 2019-02-03           53.197542
# 2019-02-10           55.977424
# 2019-02-17           53.654554
# 2019-02-24           49.042144
# 2019-03-03           47.431519
# 2019-03-10           44.728424
# 2019-03-17           50.971225
# 2019-03-24           62.706005
# 2019-03-31           52.264285
# 2019-04-07           54.576296
# 2019-04-14           49.352124
# 2019-04-21           49.409349
# 2019-04-28           48.929892
# 2019-05-05           46.280642
# 2019-05-12           56.170130
# 2019-05-19           49.713742
# 2019-05-26           56.490342
# 2019-06-02           59.588202
# 2019-06-09           53.318795
# 2019-06-16           42.830964
# 2019-06-23           47.732456
# 2019-06-30           39.774278
# 2019-07-07           54.027466
# 2019-07-14           48.576868
# 2019-07-21           51.238576
# 2019-07-28           55.273418
# 2019-08-04           56.747925
# 2019-08-11           48.336952
# 2019-08-18           54.033159
# 2019-08-25           54.034599
# 2019-09-01           50.005567
# 2019-09-08           55.310555
# 2019-09-15           53.564838
# 2019-09-22           48.862031
# 2019-09-29           46.669305
# 2019-10-06           52.351867
# 2019-10-13           51.382091
# 2019-10-20           49.029785
# 2019-10-27           53.053540
# 2019-11-03           59.461396
# 2019-11-10           50.555701
# 2019-11-17           49.681298
# 2019-11-24           51.900204
# 2019-12-01           54.539728
# 2019-12-08           52.774303
# 2019-12-15           54.515245
# 2019-12-22           49.142267
# 2019-12-29           48.763290
# 2020-01-05           24.791422

# %%
idx = pd.date_range('now', freq='H', periods=8)
example_df = pd.DataFrame({'x': np.random.rand(8)}, index=idx)

# %%
example_df.resample('2H').mean()
# Out:
#                             x
# 2021-10-01 16:00:00  0.503234
# 2021-10-01 18:00:00  0.861732
# 2021-10-01 20:00:00  0.348619
# 2021-10-01 22:00:00  0.481417

# %%
df.resample('3W').mean()
# Out:
#             coffee_consumption
# date
# 2019-01-06           10.902159
# 2019-01-27            9.744190
# 2019-02-17           10.855301
# 2019-03-10            9.413472
# 2019-03-31           11.062768
# 2019-04-21           10.222518
# 2019-05-12           10.092044
# 2019-06-02           11.052819
# 2019-06-23            9.592148
# 2019-07-14            9.491908
# 2019-08-04           10.883995
# 2019-08-25           10.426981
# 2019-09-15           10.592064
# 2019-10-06            9.858880
# 2019-10-27           10.231028
# 2019-11-17           10.646560
# 2019-12-08           10.614282
# 2019-12-29           10.161387
# 2020-01-19           12.395711

# %%
df.resample('M').sum()
# Out:
#             coffee_consumption
# date
# 2019-01-31          233.926749
# 2019-02-28          206.038853
# 2019-03-31          219.779000
# 2019-04-30          222.030626
# 2019-05-31          248.480093
# 2019-06-30          183.656493
# 2019-07-31          248.267463
# 2019-08-31          224.007066
# 2019-09-30          215.689004
# 2019-10-31          244.153522
# 2019-11-30          216.519812
# 2019-12-31          229.986526

# %% [markdown]
# ### Rolling Windows

# %%
df = df.asfreq('D').fillna(0)
df.head()
# Out:
#             coffee_consumption    weekday
# date
# 2019-01-01           14.301915    Tuesday
# 2019-01-02           12.905900  Wednesday
# 2019-01-03           10.046015   Thursday
# 2019-01-04            6.354805     Friday
# 2019-01-05            0.000000          0

# %%
df['weekly_avg'] = df.resample('W').transform('mean')

# %%
df.head(30)
# Out:
#             coffee_consumption    weekday  weekly_avg
# date
# 2019-01-01           14.301915    Tuesday    7.268106
# 2019-01-02           12.905900  Wednesday    7.268106
# 2019-01-03           10.046015   Thursday    7.268106
# 2019-01-04            6.354805     Friday    7.268106
# 2019-01-05            0.000000          0    7.268106
# 2019-01-06            0.000000          0    7.268106
# 2019-01-07            8.545563     Monday    6.626580
# 2019-01-08            9.410101    Tuesday    6.626580
# 2019-01-09            7.219271  Wednesday    6.626580
# 2019-01-10            9.338456   Thursday    6.626580
# 2019-01-11           11.872667     Friday    6.626580
# 2019-01-12            0.000000          0    6.626580
# 2019-01-13            0.000000          0    6.626580
# 2019-01-14            9.198816     Monday    7.332212
# 2019-01-15           11.753337    Tuesday    7.332212
# 2019-01-16           11.567694  Wednesday    7.332212
# 2019-01-17            9.429428   Thursday    7.332212
# 2019-01-18            9.376213     Friday    7.332212
# 2019-01-19            0.000000          0    7.332212
# 2019-01-20            0.000000          0    7.332212
# 2019-01-21           11.343439     Monday    6.921614
# 2019-01-22           10.945944    Tuesday    6.921614
# 2019-01-23            8.599186  Wednesday    6.921614
# 2019-01-24            8.141553   Thursday    6.921614
# 2019-01-25            9.421176     Friday    6.921614
# 2019-01-26            0.000000          0    6.921614
# 2019-01-27            0.000000          0    6.921614
# 2019-01-28           12.295298     Monday    7.599649
# 2019-01-29           10.336273    Tuesday    7.599649
# 2019-01-30           12.488651  Wednesday    7.599649

# %%
df['rolling_weekly_mean'] = df.coffee_consumption.rolling(7).mean()

# %%
# with a datetime index
# df.column.dt.something == df.index.something
# i.e. to extract components from a date, use, e.g. .dt.day_name() if the date is a column
# if it's an index, you don't need the .dt
df.weekday = df.index.day_name()

# %%
df.head(30)
# Out:
#             coffee_consumption    weekday  weekly_avg  rolling_weekly_mean
# date
# 2019-01-01           14.301915    Tuesday    7.268106                  NaN
# 2019-01-02           12.905900  Wednesday    7.268106                  NaN
# 2019-01-03           10.046015   Thursday    7.268106                  NaN
# 2019-01-04            6.354805     Friday    7.268106                  NaN
# 2019-01-05            0.000000   Saturday    7.268106                  NaN
# 2019-01-06            0.000000     Sunday    7.268106                  NaN
# 2019-01-07            8.545563     Monday    6.626580             7.450600
# 2019-01-08            9.410101    Tuesday    6.626580             6.751769
# 2019-01-09            7.219271  Wednesday    6.626580             5.939394
# 2019-01-10            9.338456   Thursday    6.626580             5.838314
# 2019-01-11           11.872667     Friday    6.626580             6.626580
# 2019-01-12            0.000000   Saturday    6.626580             6.626580
# 2019-01-13            0.000000     Sunday    6.626580             6.626580
# 2019-01-14            9.198816     Monday    7.332212             6.719902
# 2019-01-15           11.753337    Tuesday    7.332212             7.054650
# 2019-01-16           11.567694  Wednesday    7.332212             7.675853
# 2019-01-17            9.429428   Thursday    7.332212             7.688849
# 2019-01-18            9.376213     Friday    7.332212             7.332212
# 2019-01-19            0.000000   Saturday    7.332212             7.332212
# 2019-01-20            0.000000     Sunday    7.332212             7.332212
# 2019-01-21           11.343439     Monday    6.921614             7.638587
# 2019-01-22           10.945944    Tuesday    6.921614             7.523245
# 2019-01-23            8.599186  Wednesday    6.921614             7.099173
# 2019-01-24            8.141553   Thursday    6.921614             6.915191
# 2019-01-25            9.421176     Friday    6.921614             6.921614
# 2019-01-26            0.000000   Saturday    6.921614             6.921614
# 2019-01-27            0.000000     Sunday    6.921614             6.921614
# 2019-01-28           12.295298     Monday    7.599649             7.057594
# 2019-01-29           10.336273    Tuesday    7.599649             6.970498
# 2019-01-30           12.488651  Wednesday    7.599649             7.526136

# %%
# 3 day moving average
df.coffee_consumption.rolling(3).mean()
# Out:
# date
# 2019-01-01          NaN
# 2019-01-02          NaN
# 2019-01-03    12.417943
# 2019-01-04     9.768907
# 2019-01-05     5.466940
#                 ...
# 2019-12-27     9.742809
# 2019-12-28     5.659184
# 2019-12-29     3.154782
# 2019-12-30     4.874369
# 2019-12-31     8.263807
# Freq: D, Name: coffee_consumption, Length: 365, dtype: float64

# %%
# Moving monthly sum
df.coffee_consumption.rolling(30).sum()
# Out:
# date
# 2019-01-01           NaN
# 2019-01-02           NaN
# 2019-01-03           NaN
# 2019-01-04           NaN
# 2019-01-05           NaN
#                  ...
# 2019-12-27    228.429861
# 2019-12-28    219.936402
# 2019-12-29    205.195104
# 2019-12-30    219.818211
# 2019-12-31    229.986526
# Freq: D, Name: coffee_consumption, Length: 365, dtype: float64

# %% [markdown]
# ### Lagging and Lead

# %%
pd.concat([
    df.coffee_consumption,
    df.coffee_consumption.diff(-1),
    df.coffee_consumption.shift(),
], axis=1)
# Out:
#             coffee_consumption  coffee_consumption  coffee_consumption
# date
# 2019-01-01           14.301915            1.396015                 NaN
# 2019-01-02           12.905900            2.859885           14.301915
# 2019-01-03           10.046015            3.691210           12.905900
# 2019-01-04            6.354805            6.354805           10.046015
# 2019-01-05            0.000000            0.000000            6.354805
# ...                        ...                 ...                 ...
# 2019-12-27            9.464345            9.464345            7.513206
# 2019-12-28            0.000000            0.000000            9.464345
# 2019-12-29            0.000000          -14.623106            0.000000
# 2019-12-30           14.623106            4.454791            0.000000
# 2019-12-31           10.168315                 NaN           14.623106
#
# [365 rows x 3 columns]

# %%
# different time periods

# %%
df['coffee_consumption_tomorrow'] = df.coffee_consumption.shift(-1)

# %%
df.head(30)
# Out:
#             coffee_consumption    weekday  weekly_avg  rolling_weekly_mean  \
# date
# 2019-01-01           14.301915    Tuesday    7.268106                  NaN
# 2019-01-02           12.905900  Wednesday    7.268106                  NaN
# 2019-01-03           10.046015   Thursday    7.268106                  NaN
# 2019-01-04            6.354805     Friday    7.268106                  NaN
# 2019-01-05            0.000000   Saturday    7.268106                  NaN
# 2019-01-06            0.000000     Sunday    7.268106                  NaN
# 2019-01-07            8.545563     Monday    6.626580             7.450600
# 2019-01-08            9.410101    Tuesday    6.626580             6.751769
# 2019-01-09            7.219271  Wednesday    6.626580             5.939394
# 2019-01-10            9.338456   Thursday    6.626580             5.838314
# 2019-01-11           11.872667     Friday    6.626580             6.626580
# 2019-01-12            0.000000   Saturday    6.626580             6.626580
# 2019-01-13            0.000000     Sunday    6.626580             6.626580
# 2019-01-14            9.198816     Monday    7.332212             6.719902
# 2019-01-15           11.753337    Tuesday    7.332212             7.054650
# 2019-01-16           11.567694  Wednesday    7.332212             7.675853
# 2019-01-17            9.429428   Thursday    7.332212             7.688849
# 2019-01-18            9.376213     Friday    7.332212             7.332212
# 2019-01-19            0.000000   Saturday    7.332212             7.332212
# 2019-01-20            0.000000     Sunday    7.332212             7.332212
# 2019-01-21           11.343439     Monday    6.921614             7.638587
# 2019-01-22           10.945944    Tuesday    6.921614             7.523245
# 2019-01-23            8.599186  Wednesday    6.921614             7.099173
# 2019-01-24            8.141553   Thursday    6.921614             6.915191
# 2019-01-25            9.421176     Friday    6.921614             6.921614
# 2019-01-26            0.000000   Saturday    6.921614             6.921614
# 2019-01-27            0.000000     Sunday    6.921614             6.921614
# 2019-01-28           12.295298     Monday    7.599649             7.057594
# 2019-01-29           10.336273    Tuesday    7.599649             6.970498
# 2019-01-30           12.488651  Wednesday    7.599649             7.526136
#
#             coffee_consumption_tomorrow
# date
# 2019-01-01                    12.905900
# 2019-01-02                    10.046015
# 2019-01-03                     6.354805
# 2019-01-04                     0.000000
# 2019-01-05                     0.000000
# 2019-01-06                     8.545563
# 2019-01-07                     9.410101
# 2019-01-08                     7.219271
# 2019-01-09                     9.338456
# 2019-01-10                    11.872667
# 2019-01-11                     0.000000
# 2019-01-12                     0.000000
# 2019-01-13                     9.198816
# 2019-01-14                    11.753337
# 2019-01-15                    11.567694
# 2019-01-16                     9.429428
# 2019-01-17                     9.376213
# 2019-01-18                     0.000000
# 2019-01-19                     0.000000
# 2019-01-20                    11.343439
# 2019-01-21                    10.945944
# 2019-01-22                     8.599186
# 2019-01-23                     8.141553
# 2019-01-24                     9.421176
# 2019-01-25                     0.000000
# 2019-01-26                     0.000000
# 2019-01-27                    12.295298
# 2019-01-28                    10.336273
# 2019-01-29                    12.488651
# 2019-01-30                     9.035046

# %% [markdown]
# ## Strftime

# %% [markdown]
# [strftime reference](https://codeupclassroom.github.io/germain-time-series/)

# %%
df.index.strftime('%b %d, %Y')[:4]
# Out:
# Index(['Jan 01, 2019', 'Jan 02, 2019', 'Jan 03, 2019', 'Jan 04, 2019'], dtype='object', name='date')

# %% [markdown]
# ## Timezones

# %%
np.random.seed(13)

idx = pd.date_range('now', freq='H', periods=100)
hourly_df = pd.DataFrame({'x': np.random.choice(list('abc'), 100), 'y': np.random.rand(100)}, index=idx)

# %%
hourly_df
# Out:
#                             x         y
# 2021-10-01 16:07:27.704495  c  0.792424
# 2021-10-01 17:07:27.704495  a  0.012453
# 2021-10-01 18:07:27.704495  c  0.747946
# 2021-10-01 19:07:27.704495  a  0.990472
# 2021-10-01 20:07:27.704495  c  0.189689
# ...                        ..       ...
# 2021-10-05 15:07:27.704495  c  0.639644
# 2021-10-05 16:07:27.704495  a  0.284556
# 2021-10-05 17:07:27.704495  c  0.914614
# 2021-10-05 18:07:27.704495  b  0.174527
# 2021-10-05 19:07:27.704495  b  0.968520
#
# [100 rows x 2 columns]

# %%
hourly_df.index.tz

# %%
hourly_df.index.tz is None
# Out:
# True

# %%
hourly_df.tz_localize('America/Chicago')
# Out:
#                                   x         y
# 2021-10-01 16:07:27.704495-05:00  c  0.792424
# 2021-10-01 17:07:27.704495-05:00  a  0.012453
# 2021-10-01 18:07:27.704495-05:00  c  0.747946
# 2021-10-01 19:07:27.704495-05:00  a  0.990472
# 2021-10-01 20:07:27.704495-05:00  c  0.189689
# ...                              ..       ...
# 2021-10-05 15:07:27.704495-05:00  c  0.639644
# 2021-10-05 16:07:27.704495-05:00  a  0.284556
# 2021-10-05 17:07:27.704495-05:00  c  0.914614
# 2021-10-05 18:07:27.704495-05:00  b  0.174527
# 2021-10-05 19:07:27.704495-05:00  b  0.968520
#
# [100 rows x 2 columns]

# %%
hourly_df.tz_localize(None)
# Out:
#                             x         y
# 2021-10-01 16:07:27.704495  c  0.792424
# 2021-10-01 17:07:27.704495  a  0.012453
# 2021-10-01 18:07:27.704495  c  0.747946
# 2021-10-01 19:07:27.704495  a  0.990472
# 2021-10-01 20:07:27.704495  c  0.189689
# ...                        ..       ...
# 2021-10-05 15:07:27.704495  c  0.639644
# 2021-10-05 16:07:27.704495  a  0.284556
# 2021-10-05 17:07:27.704495  c  0.914614
# 2021-10-05 18:07:27.704495  b  0.174527
# 2021-10-05 19:07:27.704495  b  0.968520
#
# [100 rows x 2 columns]

# %%
hourly_df = hourly_df.tz_localize('America/New_York')

# %%
hourly_df.head(4)
# Out:
#                                   x         y
# 2021-10-01 16:07:27.704495-04:00  c  0.792424
# 2021-10-01 17:07:27.704495-04:00  a  0.012453
# 2021-10-01 18:07:27.704495-04:00  c  0.747946
# 2021-10-01 19:07:27.704495-04:00  a  0.990472

# %%
hourly_df.tz_convert('America/Los_Angeles').head(4)
# Out:
#                                   x         y
# 2021-10-01 13:07:27.704495-07:00  c  0.792424
# 2021-10-01 14:07:27.704495-07:00  a  0.012453
# 2021-10-01 15:07:27.704495-07:00  c  0.747946
# 2021-10-01 16:07:27.704495-07:00  a  0.990472

# %% [markdown]
# [Wikipedia: List of Time Zones](https://en.wikipedia.org/wiki/List_of_tz_database_time_zones)

# %% [markdown]
# ## Timedeltas

# %%
start_date = pd.to_datetime('20210614')
today = pd.to_datetime('20211001')
graduation_date = pd.to_datetime('20211207')

# %%
(today - start_date) / pd.Timedelta('1d')
# Out:
# 109.0

# %%
days_since_start = (today - start_date) / pd.Timedelta('1d')

# %%
total_days = (graduation_date - start_date) / pd.Timedelta('1d')

# %%
days_since_start / total_days
# Out:
# 0.6193181818181818

# %%
graduation_date - today
# Out:
# Timedelta('67 days 00:00:00')

# %%
df['days_since_end'] = (df.index.max() - df.index) / pd.Timedelta('1d')

# %%
df
# Out:
#             coffee_consumption    weekday  weekly_avg  rolling_weekly_mean  \
# date
# 2019-01-01           14.301915    Tuesday    7.268106                  NaN
# 2019-01-02           12.905900  Wednesday    7.268106                  NaN
# 2019-01-03           10.046015   Thursday    7.268106                  NaN
# 2019-01-04            6.354805     Friday    7.268106                  NaN
# 2019-01-05            0.000000   Saturday    7.268106                  NaN
# ...                        ...        ...         ...                  ...
# 2019-12-27            9.464345     Friday    6.966184             6.966184
# 2019-12-28            0.000000   Saturday    6.966184             6.966184
# 2019-12-29            0.000000     Sunday    6.966184             6.966184
# 2019-12-30           14.623106     Monday   12.395711             7.746276
# 2019-12-31           10.168315    Tuesday   12.395711             7.717121
#
#             coffee_consumption_tomorrow  days_since_end
# date
# 2019-01-01                    12.905900           364.0
# 2019-01-02                    10.046015           363.0
# 2019-01-03                     6.354805           362.0
# 2019-01-04                     0.000000           361.0
# 2019-01-05                     0.000000           360.0
# ...                                 ...             ...
# 2019-12-27                     0.000000             4.0
# 2019-12-28                     0.000000             3.0
# 2019-12-29                    14.623106             2.0
# 2019-12-30                    10.168315             1.0
# 2019-12-31                          NaN             0.0
#
# [365 rows x 6 columns]

# %%
df['days_since_max'] = (df.index.max() - df.index) // pd.Timedelta('1d')
df.tail(10)
# Out:
#             coffee_consumption    weekday  weekly_avg  rolling_weekly_mean  \
# date
# 2019-12-22            0.000000     Sunday    7.020324             7.020324
# 2019-12-23            9.162464     Monday    6.966184             6.595658
# 2019-12-24           10.372400    Tuesday    6.966184             6.408350
# 2019-12-25           12.250875  Wednesday    6.966184             6.864358
# 2019-12-26            7.513206   Thursday    6.966184             6.929627
# 2019-12-27            9.464345     Friday    6.966184             6.966184
# 2019-12-28            0.000000   Saturday    6.966184             6.966184
# 2019-12-29            0.000000     Sunday    6.966184             6.966184
# 2019-12-30           14.623106     Monday   12.395711             7.746276
# 2019-12-31           10.168315    Tuesday   12.395711             7.717121
#
#             coffee_consumption_tomorrow  days_since_end  days_since_max
# date
# 2019-12-22                     9.162464             9.0               9
# 2019-12-23                    10.372400             8.0               8
# 2019-12-24                    12.250875             7.0               7
# 2019-12-25                     7.513206             6.0               6
# 2019-12-26                     9.464345             5.0               5
# 2019-12-27                     0.000000             4.0               4
# 2019-12-28                     0.000000             3.0               3
# 2019-12-29                    14.623106             2.0               2
# 2019-12-30                    10.168315             1.0               1
# 2019-12-31                          NaN             0.0               0

# %% [markdown]
# ## Plotting

# %%
df.resample('W').sum().coffee_consumption.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df[['coffee_consumption']].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df.resample('3M').mean().plot(marker='o')
# Out:
# <AxesSubplot:xlabel='date'>
